# %% [markdown]
# # Week 1 — Problem Definition & Dataset Exploration (Easy Version)
# ### ML Project (Common Project Model — Phase 1)
# **Dataset:** Vehicle Insurance Fraud Data
# **Library used:** Pandas (simple, beginner-friendly commands)
# **Student Name:** _______________
# **Roll No / Enrolment No:** _______________
# **Date:** _______________
#
# ---

# %% [markdown]
# ## 1. Problem Statement
#
# We want to predict whether an insurance claim is **fraudulent (Y)** or **genuine (N)**, using information about the driver, vehicle, and claim (age, income, vehicle details, claim amount, etc.).
#
# **Target Column:** `fraud reported`
#
# **Type of Problem:** Classification (Yes/No prediction)

# %% [markdown]
# ## 2. Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## 3. Load the Dataset

# %%
df = pd.read_csv('insurance_fraud_data.csv')
df.head()
# Out:
#    claim_number  age_of_driver gender marital_status  safety_rating  \
# 0        414724             39      M              1             73
# 1        269568             33      M              1             72
# 2        974592             31      M              1             76
# 3        995328             53      F              1             93
# 4       1140480             41      M              1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_category vehicle_price vehicle_color  total_claim injury_claim  \
# ...

# %% [markdown]
# ---
# ## 4. Simple Questions (Easy Level)
#
# Just run each cell and note down what you observe below it. No advanced code, just basic pandas.

# %% [markdown]
# ### Q1. How many rows and columns are in the dataset?

# %%
df.shape
# Out:
# (12002, 29)

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q2. What are the column names?

# %%
df.columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safety_rating', 'annual_income', 'high_education', 'address_change',
#        'property_status', 'zip_code', 'claim_date', 'claim_day_of_week',
#        'accident_site', 'past_num_of_claims', 'witness_present', 'liab_prct',
#        'channel', 'police_report', 'age_of_vehicle', 'vehicle_category',
#        'vehicle_price', 'vehicle_color', 'total_claim', 'injury_claim',
#        'policy deductible', 'annual premium', 'days open', 'form defects',
#        'fraud reported'],
#       dtype='object')

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q3. What do the first 5 rows look like?

# %%
df.head()
# Out:
#    claim_number  age_of_driver gender marital_status  safety_rating  \
# 0        414724             39      M              1             73
# 1        269568             33      M              1             72
# 2        974592             31      M              1             76
# 3        995328             53      F              1             93
# 4       1140480             41      M              1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_category vehicle_price vehicle_color  total_claim injury_claim  \
# ...

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q4. What do the last 5 rows look like?

# %%
df.tail()
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# 11997        66505.6               1               1            Rent
# 11998        23315.2               1               0            Rent
# 11999        66505.6               0               1             Own
# 12000        76409.6               1               0             Own
# 12001        70915.2               1               0            Rent
#
#        zip_code  ... vehicle_category vehicle_price vehicle_color  \
# ...

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q5. What is the data type of each column (number, text, etc.)?

# %%
df.dtypes
# Out:
# claim_number            int64
# age_of_driver           int64
# gender                 object
# marital_status         object
# safety_rating           int64
# annual_income         float64
# high_education          int64
# address_change          int64
# property_status        object
# zip_code                int64
# claim_date             object
# claim_day_of_week      object
# accident_site          object
# past_num_of_claims      int64
# witness_present        object
# liab_prct               int64
# channel                object
# police_report           int64
# age_of_vehicle         object
# vehicle_category       object
# vehicle_price         float64
# vehicle_color          object
# total_claim           float64
# injury_claim           object
# policy deductible       int64
# annual premium        float64
# days open             float64
# form defects            int64
# fraud reported         object
# dtype: object

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q6. Is there any missing (empty) data in the dataset?

# %%
df.isnull().sum()
# Out:
# claim_number          0
# age_of_driver         0
# gender                0
# marital_status        0
# safety_rating         0
# annual_income         0
# high_education        0
# address_change        0
# property_status       0
# zip_code              0
# claim_date            0
# claim_day_of_week     0
# accident_site         0
# past_num_of_claims    0
# witness_present       0
# liab_prct             0
# channel               0
# police_report         0
# age_of_vehicle        0
# vehicle_category      0
# vehicle_price         0
# vehicle_color         0
# total_claim           0
# injury_claim          0
# policy deductible     0
# annual premium        0
# days open             0
# form defects          0
# fraud reported        8
# dtype: int64

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q7. What is the average (mean) age of drivers?

# %%
df['age_of_driver'].mean()
# Out:
# np.float64(43.52516247292118)

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q8. What is the youngest and oldest driver age in the dataset?

# %%
print('Youngest:', df['age_of_driver'].min())
print('Oldest:', df['age_of_driver'].max())
# Out:
# Youngest: 19
# Oldest: 278

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q9. What is the average annual income of policyholders?

# %%
df['annual_income'].mean()
# Out:
# np.float64(63658.22653357774)

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q10. What is the average total claim amount?

# %%
df['total_claim'].mean()
# Out:
# np.float64(22861.534958498665)

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q11. How many claims were fraudulent (Y) vs genuine (N)?

# %%
df['fraud reported'].value_counts()
# Out:
# fraud reported
# N    9043
# Y    2951
# Name: count, dtype: int64

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q12. What are the different vehicle categories in the dataset?

# %%
df['vehicle_category'].unique()
# Out:
# array(['Large', 'Medium', 'Compact'], dtype=object)

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q13. What are the different claim channels, and how many claims came through each?

# %%
df['channel'].value_counts()
# Out:
# channel
# Broker    6370
# Phone     3840
# Online    1792
# Name: count, dtype: int64

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q14. How many claims had a witness present?

# %%
df['witness_present'].value_counts()
# Out:
# witness_present
# 0    9070
# 1    2844
# *      88
# Name: count, dtype: int64

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q15. How many claims had a police report filed?

# %%
df['police_report'].value_counts()
# Out:
# police_report
# 1    7214
# 0    4788
# Name: count, dtype: int64

# %% [markdown]
# **My Observation:** _write here_

# %% [markdown]
# ### Q16. What is the simple statistical summary (min, max, mean, etc.) of all number columns?

# %%
df.describe()
# Out:
#        claim_number  age_of_driver  safety_rating  annual_income  \
# count  1.200200e+04   12002.000000   12002.000000   12002.000000
# mean   3.119801e+08      43.525162      73.702966   63658.226534
# std    1.795997e+08      12.201298      15.378967   17289.704559
# min    1.866240e+05      19.000000       2.000000      -1.600000
# 25%    1.561887e+08      35.000000      66.000000   56899.200000
# 50%    3.121908e+08      43.000000      76.000000   60899.200000
# 75%    4.677938e+08      51.000000      85.000000   64697.600000
# max    6.220385e+08     278.000000     100.000000  257313.600000
#
#        high_education  address_change      zip_code  past_num_of_claims  \
# count    12002.000000    12002.000000  12002.000000        12002.000000
# mean         0.698134        0.576737  49762.387269            0.494918
# std          0.459087        0.494097  29133.180765            0.956002
# min          0.000000        0.000000      0.000000            0.000000
# ...

# %% [markdown]
# **My Observation:** _write here_
